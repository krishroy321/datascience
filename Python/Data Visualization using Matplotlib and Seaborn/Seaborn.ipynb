# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="darkgrid")

# %%
x = np.array([1,3,4,5,6,77,7,8,8,4,34,3,43,43,78,89,90])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
